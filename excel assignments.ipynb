# %% [markdown]
# # EXCEL ASSIGNMENT 1

# %%
q1-  date format changes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # EXCEL ASSIGNMENT 2

# %%
COUNTIF-SUMIF EXCERCISE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assignment_3

# %% [markdown]
# column count use this formula = =IF(COUNTIF($D$1:D2,D2)=1,COUNTIF(D:D,D2),"")
# Create new column for remove - values = =LEFT(SUBSTITUTE(IF(ISNUMBER(FIND("(",A2)),SUBSTITUTE(A2,"("," "),SUBSTITUTE(A2&"-","-","%"))," ","%",2),FIND("%",SUBSTITUTE(IF(ISNUMBER(FIND("(",A2)),SUBSTITUTE(A2,"("," "),SUBSTITUTE(A2&"-","-","%"))," ","%",2))-1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assignment_4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assignment_5
# Write a formula which can be dragged right and down to generate a multiplication table. (Generate Multiplication Table.xlsx)

# %% [markdown]
# formula = '$A2*B$1'
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assignment_6
#
# q1. Fill in the table of 2016 sales by month by store using only 1 SUMIFS Formula (Many Sales Sample Data)
#
#
# formula = =SUMIFS($C$2:$C$150000,$B$2:$B$150000,$E16,$A$2:$A$150000,F$15) after than drag and drop in all columns get this proper data.
#
#
# q2.Fill in the table of 2016 sales by month by store using only 1 SUMPRODUCT Formula (Many Sales Sample Data)
#
#
# ans. formula =SUMPRODUCT(($C$2:$C$150000)*($B$2:$B$150000 =$E3)*($A$2:$A$150000 =F$2)) try this after that you need to drag and drop all the columns.
#
# q3 .Create a Pivot Table that only shoes the 2016 sales by month by store. (Many Sales Sample Data)
#
#     ans. Create a pivot table with all data and filter the year 2016 sales create month wise, in columns store ids,  in rows new dates.
#
#
#
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assignment_7
#
# Q1 - write a formula which returns "Palindrome" or "Not Palindrome" for a given word in (palindrome.xslx)
#
#
# aNS. =IF(SUMPRODUCT(--(MID(SUBSTITUTE(B4," ",""),ROW(INDIRECT("1:"&LEN(SUBSTITUTE(B4," ","")))),1)=MID(SUBSTITUTE(B4," ",""),LEN(SUBSTITUTE(B4," ",""))+1-ROW(INDIRECT("1:"&LEN(SUBSTITUTE(B4," ","")))),1)))=LEN(SUBSTITUTE(B4," ","")),"Palindrome","Not Palindrome")
#
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assignment_8
#
# q1 - The Challenge before you is to write a formula to clean the data. If you perform any mathematical operation on the data, it will return #VALUE error. You need to clean the data through a formula. (Problem-Workbook)
#
#
# Ans.  just use to TRIM function to clean data.
#
#
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assignment_9
#
# q1 - Find the maximum and minimum and sum of all the radiation amounts.
#
# ans. Maximum	Minium	sum total
# 188	114	5966
#
#
# radiation amount - 155
#
# Find the count and Rank-  40 & rank
# Compute the mean and standard deviation of the radiation amounts.  - mean = 149.15 & std = 14.98469304
#
# Describe a certain objective a researcher might have had in mind when collecting this data.-  The most critical objective of data collection is ensuring that information-rich and reliable data is collected for statistical analysis so that data-driven decisions can be made for research.
#
#
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Assignment_10
#
# q - Produce the Sum for Merged Cells Headers (Sum-for-Merged-Cells.xlsx)
# You need to write a single formula which can be dragged right and down to generate the sum for below table
#
#
#
# Ans. =SUM(OFFSET($A$1,ROWS($1:1),MATCH(B$13,$1:$1,0)-1,,IFERROR(MATCH(C$13,$1:$1,0),COUNTA($2:$2)+1)-MATCH(B$13,$1:$1,0)))
#
#
#
# ![image.png](attachment:image.png)
